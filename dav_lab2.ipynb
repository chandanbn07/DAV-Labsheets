# %% [markdown]
# pandas library

# %% [markdown]
# series

# %%
import pandas as pd
import numpy as np
d=np.array(['a','b','c','d'])
s=pd.Series(d)
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd
import numpy as np
d=np.array(['a','b','c','d'])
s=pd.Series(d,index=[100,200,300,400])
s
# Out:
# 100    a
# 200    b
# 300    c
# 400    d
# dtype: object

# %%
import pandas as pd
import numpy as np
s=pd.Series(['a','b','c','d'],index=[100,200,300,400])
s
# Out:
# 100    a
# 200    b
# 300    c
# 400    d
# dtype: object

# %%
import pandas as pd
import numpy as np
d={'a':0.,'b':1.,'c':2.,}
s=pd.Series(d,index=['b','c','d','a'])
print(s)
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
s=pd.Series(5,index=[0,1,2,3])
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
#retrieve the first element
print(s)
print(s[0])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# 1

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
#retrieve the first tree element
print(s[:3])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
#retrieve a single element
print(s['a'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# 1

# %%
import pandas as pd
import numpy as np
d=np.array([1,2,3,4,5])
s=pd.Series(d,dtype='float')
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %% [markdown]
# data frame

# %%
import pandas as pd
a=pd.DataFrame()
a
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
d=[1,2,3,4]
a=pd.DataFrame(d)
a
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
import pandas as pd
d=[1,2,3,4]
a=pd.DataFrame(d,index=['a','b','c','d'])
a
# Out:
#    0
# a  1
# b  2
# c  3
# d  4

# %%
import pandas as pd
d=[['Alex',10],['bob',11],['clarke',12]]
a=pd.DataFrame(d,columns=['name','age'])
a
# Out:
#      name  age
# 0    Alex   10
# 1     bob   11
# 2  clarke   12

# %%
import pandas as pd
d=[['Alex',10],['bob',11],['clarke',12]]
a=pd.DataFrame(d,columns=['name','age'],dtype='float')
a
# Out:
# <ipython-input-51-8834ff0233a9>:3: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   a=pd.DataFrame(d,columns=['name','age'],dtype='float')
#      name   age
# 0    Alex  10.0
# 1     bob  11.0
# 2  clarke  12.0

# %%
import pandas as pd
d={'name':['tom','jack','steve'],'age':[12,13,14]}
pd.DataFrame(d,index=['rank1','rank2','rank3'])
# Out:
#         name  age
# rank1    tom   12
# rank2   jack   13
# rank3  steve   14

# %%
import pandas as pd
d=[{'a':1,'b':2},{'a':5,'b':10,'c':20}] #dictionary
df=pd.DataFrame(d)
df
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
import pandas as pd
d=[{'a':1,'b':2},{'a':5,'b':10,'c':20}] #dictionary
df=pd.DataFrame(d,index=['first','second'])
df
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
d=[{'a':1,'b':2},{'a':5,'b':10,'c':20}]
df1=pd.DataFrame(d,index=['first','second'],columns=['a','b'])
df2=pd.DataFrame(d,index=['first','second'],columns=['a','b1'])
print(df1)
print(df2)
# Out:
#         a   b
# first   1   2
# second  5  10
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
d={'one': pd.Series([1,2,3],index=['a','b','c']),
'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
d={'one': pd.Series([1,2,3],index=['a','b','c']),
'two':pd.Series([1,2,3,4],index=['a','b','c','d']),'three': pd.Series([10,20,30],index=['a','b','c'])}
df=pd.DataFrame(d)
print('our dataframe is: ')
print(df)
print('deleting the first column using del function')
del(df['one'])
print(df)
print('deleting the first column using pop function')
df.pop('two')
# Out:
# our dataframe is:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# deleting the first column using del function
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
# deleting the first column using pop function
# a    1
# b    2
# c    3
# d    4
# Name: two, dtype: int64

# %%
d={'one': pd.Series([1,2,3],index=['a','b','c']),
'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
df.loc['b']
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
d={'one': pd.Series([1,2,3],index=['a','b','c']),
'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
df[2:4]
# Out:
#    one  two
# c  3.0    3
# d  NaN    4

# %%
df=pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df=df.append(df2)
print(df)
df=df.drop(0) #drop row with label 0
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
#    a  b
# 1  3  4
# 1  7  8
# <ipython-input-30-fe169d392eb3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2)

# %%
import pandas as pd
df=pd.read_csv('/content/heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info
# Out:
# <bound method DataFrame.info of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...
