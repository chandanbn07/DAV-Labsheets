# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f','g','h'])
print(df['one'].isnull())
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
print(df)
df=df.reindex(['a','b','c','d','e','f','g','h'])
print(df['one'].isnull())
# Out:
#         one       two     three
# a -0.897085 -0.595825 -0.470388
# c -2.213332  0.346503 -0.508660
# e -0.922364 -2.394701 -2.084262
# f -1.071533  0.352844  1.216785
# h  0.080120 -0.725891  0.989218
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(3,3),index=['a','c','e'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f','g','h'])
print(df)
print("NaN replaced with '0':")
print(df.fillna(0))
# Out:
#         one       two     three
# a  0.664910  1.277152 -1.068908
# b       NaN       NaN       NaN
# c -1.749915 -0.698087 -0.968558
# d       NaN       NaN       NaN
# e  0.193257  0.341208 -0.346321
# f       NaN       NaN       NaN
# g       NaN       NaN       NaN
# h       NaN       NaN       NaN
# NaN replaced with '0':
#         one       two     three
# a  0.664910  1.277152 -1.068908
# b  0.000000  0.000000  0.000000
# c -1.749915 -0.698087 -0.968558
# d  0.000000  0.000000  0.000000
# e  0.193257  0.341208 -0.346321
# f  0.000000  0.000000  0.000000
# g  0.000000  0.000000  0.000000
# h  0.000000  0.000000  0.000000

# %%
print(df)
print('---------------')
print(df.fillna(method='pad')) #forward filling--------------
# Out:
#         one       two     three
# a  0.664910  1.277152 -1.068908
# b       NaN       NaN       NaN
# c -1.749915 -0.698087 -0.968558
# d       NaN       NaN       NaN
# e  0.193257  0.341208 -0.346321
# f       NaN       NaN       NaN
# g       NaN       NaN       NaN
# h       NaN       NaN       NaN
# ---------------
#         one       two     three
# a  0.664910  1.277152 -1.068908
# b  0.664910  1.277152 -1.068908
# c -1.749915 -0.698087 -0.968558
# d -1.749915 -0.698087 -0.968558
# e  0.193257  0.341208 -0.346321
# f  0.193257  0.341208 -0.346321
# g  0.193257  0.341208 -0.346321
# h  0.193257  0.341208 -0.346321

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
print(df)
df=df.reindex(['a','b','c','d','e','f','g','h'])
print(df.fillna(method='bfill'))#backward filling-----------------------

# %%
df=pd.DataFrame(np.random.randn(5,3),index=['a','c','e','f','h'],columns=['one','two','three'])
print(df)
df=df.reindex(['a','b','c','d','e','f','g','h'])
print(df)
print(df.dropna())
# Out:
#         one       two     three
# a  0.213970  0.818086 -1.391518
# c -1.850818 -1.084886 -0.123221
# e -1.333107  0.355879  2.279890
# f -0.927647  2.359246  0.049232
# h -0.298593  1.032517  1.877301
#         one       two     three
# a  0.213970  0.818086 -1.391518
# b       NaN       NaN       NaN
# c -1.850818 -1.084886 -0.123221
# d       NaN       NaN       NaN
# e -1.333107  0.355879  2.279890
# f -0.927647  2.359246  0.049232
# g       NaN       NaN       NaN
# h -0.298593  1.032517  1.877301
#         one       two     three
# a  0.213970  0.818086 -1.391518
# c -1.850818 -1.084886 -0.123221
# e -1.333107  0.355879  2.279890
# f -0.927647  2.359246  0.049232
# h -0.298593  1.032517  1.877301

# %%
d=pd.read_csv('/content/2,1 dataset titanic (1).csv')
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.info()
d.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
cols=['Name','Ticket','Cabin']
d=d.drop(cols,axis=1)
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
f=d.dropna()
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
dummies=[]
cols=['Pclass','Sex','Embarked']
for col in cols:
   dummies.append(pd.get_dummies(d[col]))
print(d)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
td=pd.concat(dummies,axis=0)
td
# Out:
#        1    2    3  female  male    C    Q    S
# 0    0.0  0.0  1.0     NaN   NaN  NaN  NaN  NaN
# 1    1.0  0.0  0.0     NaN   NaN  NaN  NaN  NaN
# 2    0.0  0.0  1.0     NaN   NaN  NaN  NaN  NaN
# 3    1.0  0.0  0.0     NaN   NaN  NaN  NaN  NaN
# 4    0.0  0.0  1.0     NaN   NaN  NaN  NaN  NaN
# ..   ...  ...  ...     ...   ...  ...  ...  ...
# 886  NaN  NaN  NaN     NaN   NaN  0.0  0.0  1.0
# 887  NaN  NaN  NaN     NaN   NaN  0.0  0.0  1.0
# 888  NaN  NaN  NaN     NaN   NaN  0.0  0.0  1.0
# 889  NaN  NaN  NaN     NaN   NaN  1.0  0.0  0.0
# 890  NaN  NaN  NaN     NaN   NaN  0.0  1.0  0.0
#
# [2673 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
d=[[-1,2],[-0.5,6],[0,10],[1,18]]
scaler=MinMaxScaler()
print(scaler.fit(d))
print('-------')
MinMaxScaler()
print(scaler.data_max_)
print('-------')
# Out:
# MinMaxScaler()
# -------
# [ 1. 18.]
# -------

# %%
from numpy import asarray
from sklearn.preprocessing import StandardScaler
d=asarray([[100,10000],[50,0.005],[88,0.07]])
print(d)
scaler=StandardScaler()
scaled=scaler.fit_transform(d)
print(scaled)
# Out:
# [[1.0e+02 1.0e+04]
#  [5.0e+01 5.0e-03]
#  [8.8e+01 7.0e-02]]
# [[ 0.96969743  1.41421356]
#  [-1.37634474 -0.70711368]
#  [ 0.40664731 -0.70709989]]
